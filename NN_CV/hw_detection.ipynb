# %% [markdown]
# В данном задании вам предстоит помочь [The Nature Conservancy](https://www.nature.org/en-us/about-us/where-we-work/united-states/california/) в борьбе с рыбаками-браконьерами. Необходимо по снимкам с камеры на рыболовецком судне классифицировать улов. За основу решения предлагается взять модель детектора:
# [github.com...tion.ipynb](https://github.com/a4tunado/lectures/blob/master/007/007-detection.ipynb). Решение необходимо прислать в виде ссылки на ipython-ноутбук с указанием значения метрики на [Leaderboard](https://www.kaggle.com/c/the-nature-conservancy-fisheries-monitoring/leaderboard).

# %% [markdown]
# Based on https://www.kaggle.com/code/polinalatypova/notebook21f74d1cf5/notebook

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tqdm.notebook import tqdm
import zipfile
from scipy.special import softmax
from matplotlib import pyplot as plt

# %%
# !pip install -q kaggle

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-381ae2d8-8746-47fa-8907-27139e7fff0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-381ae2d8-8746-47fa-8907-27139e7fff0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir /root/.kaggle
# !mv kaggle.json /root/.kaggle/kaggle.json
# !kaggle competitions download -c the-nature-conservancy-fisheries-monitoring
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# the-nature-conservancy-fisheries-monitoring.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
z = zipfile.ZipFile('data.zip')

# %%
with zipfile.ZipFile("the-nature-conservancy-fisheries-monitoring.zip","r") as z:
    z.extractall(".")
with zipfile.ZipFile("test_stg1.zip","r") as z:
    z.extractall(".")
# !pip install py7zr
import py7zr
with py7zr.SevenZipFile("test_stg2.7z", mode='r') as z:
    z.extractall()

with zipfile.ZipFile("train.zip","r") as z:
    z.extractall(".")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: py7zr in /usr/local/lib/python3.7/dist-packages (0.19.0)
# Requirement already satisfied: texttable in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.6.4)
# Requirement already satisfied: inflate64>=0.1.2 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.1.4)
# Requirement already satisfied: pybcj>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.6.1)
# Requirement already satisfied: multivolumefile>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.2.3)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from py7zr) (3.15.0)
# Requirement already satisfied: brotli>=1.0.9 in /usr/local/lib/python3.7/dist-packages (from py7zr) (1.0.9)
# Requirement already satisfied: pyzstd>=0.14.4 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.15.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from py7zr) (5.4.8)
# Requirement already satisfied: pyppmd<0.19.0,>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from py7zr) (0.18.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from py7zr) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->py7zr) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->py7zr) (3.8.0)

# %%
with zipfile.ZipFile('/content/data.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import os
import json
from glob import glob

TRAIN_PREFIX = 'train'

def load_annotations():
    boxes = dict()
    for path in glob('data/fish/boxes/*.json'):
        label = os.path.basename(path).split('_', 1)[0]
        with open(path) as src:
            for annotation in json.load(src):
                basename = os.path.basename(annotation['filename'])
                annotation['filename'] = os.path.join(
                    TRAIN_PREFIX, label.upper(), basename)
                for rect in annotation['annotations']:
                    rect['x'] += rect['width'] / 2
                    rect['y'] += rect['height'] / 2
                if os.path.isfile(annotation['filename']):
                    boxes.setdefault(label, []).append(annotation)
    return boxes

def draw_boxes(annotation, rectangles=None, image_size=None):
    
    def _draw(img, rectangles, scale_x, scale_y, color=(0, 255, 0)):
        for rect in rectangles:
            pt1 = (int((rect['x'] - rect['width'] / 2) * scale_x),
                   int((rect['y'] - rect['height'] / 2) * scale_y))
            pt2 = (int((rect['x'] + rect['width'] / 2) * scale_x),
                   int((rect['y'] + rect['height'] / 2) * scale_y))
            img = cv2.rectangle(img.copy(), pt1, pt2, 
                                color=color, thickness=4)
        return img
    
    scale_x, scale_y = 1., 1.
    
    img = cv2.imread(annotation['filename'], cv2.IMREAD_COLOR)[...,::-1]
    if image_size is not None:
        scale_x = 1. * image_size[0] / img.shape[1]
        scale_y = 1. * image_size[1] / img.shape[0]
        img = cv2.resize(img, image_size)
        
    img = _draw(img, annotation.get('annotations', []), scale_x, scale_y)
    
    if rectangles is not None:
        img = _draw(img, rectangles, 1., 1., (255, 0, 0))

    return img

# %%
boxes = load_annotations()  # загружаем разметку детекций
boxes
# Out:
# {'alb': [{'annotations': [{'class': 'rect',
#      'height': 151.06975503141317,
#      'width': 383.68430384213445,
#      'x': 739.0000000000025,
#      'y': 268.8946201973347}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07917.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 65.00000000000023,
#      'width': 166.00000000000063,
#      'x': 552.0000000000019,
#      'y': 480.5000000000017},
#     {'class': 'rect',
#      'height': 143.0000000000005,
#      'width': 98.00000000000036,
#      'x': 141.0000000000005,
#      'y': 566.500000000002}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07915.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 85.00000000000034,
#      'width': 251.00000000000085,
#      'x': 459.5000000000016,
#      'y': 286.500000000001}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07914.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 231.0000000000008,
#      'width': 199.00000000000068,
#      'x': 487.5000000000017,
#      'y': 241.50000000000085}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07912.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 158.0000000000005,
#      'width': 73.00000000000027,
#      'x': 152.50000000000054,
#      'y': 574.000000000002}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07904.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 150.0000000000005,
#      'width': 90.00000000000034,
#      'x': 683.0000000000025,
#      'y': 407.0000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07903.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 113.0000000000004,
#      'width': 323.0000000000012,
#      'x': 436.5000000000016,
#      'y': 118.50000000000043},
#     {'class': 'rect',
#      'height': 109.0000000000004,
#      'width': 272.00000000000097,
#      'x': 631.0000000000023,
#      'y': 231.50000000000082}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07892.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 191.00000000000063,
#      'width': 85.00000000000034,
#      'x': 698.5000000000025,
#      'y': 525.5000000000018},
#     {'class': 'rect',
#      'height': 93.00000000000034,
#      'width': 96.00000000000034,
#      'x': 886.0000000000032,
#      'y': 356.50000000000125}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07890.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 160.00000000000057,
#      'width': 235.0000000000008,
#      'x': 882.5000000000032,
#      'y': 92.00000000000034}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07885.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 152.00000000000057,
#      'width': 55.00000000000023,
#      'x': 596.5000000000022,
#      'y': 446.0000000000016}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07883.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 162.00000000000057,
#      'width': 85.00000000000031,
#      'x': 146.5000000000005,
#      'y': 568.000000000002},
#     {'class': 'rect',
#      'height': 48.00000000000017,
#      'width': 97.00000000000034,
#      'x': 188.50000000000068,
#      'y': 442.0000000000016},
#     {'class': 'rect',
#      'height': 49.00000000000017,
#      'width': 151.00000000000057,
#      'x': 486.50000000000176,
#      'y': 418.5000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07879.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 250.0000000000009,
#      'width': 102.00000000000023,
#      'x': 1060.0000000000036,
#      'y': 667.0000000000025},
#     {'class': 'rect',
#      'height': 245.0000000000009,
#      'width': 156.00000000000057,
#      'x': 273.00000000000097,
#      'y': 470.5000000000017}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07878.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 156.00000000000057,
#      'width': 352.00000000000136,
#      'x': 768.0000000000027,
#      'y': 159.00000000000057}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07877.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 187.00000000000063,
#      'width': 88.00000000000034,
#      'x': 699.0000000000025,
#      'y': 525.5000000000018},
#     {'class': 'rect',
#      'height': 87.00000000000034,
#      'width': 104.00000000000034,
#      'x': 889.0000000000032,
#      'y': 352.50000000000125}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07876.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 35.00000000000017,
#      'width': 166.0000000000005,
#      'x': 506.0000000000018,
#      'y': 408.5000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07874.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 179.00000000000068,
#      'width': 210.0000000000008,
#      'x': 716.0000000000025,
#      'y': 537.5000000000019}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07871.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 107.00000000000034,
#      'width': 119.00000000000045,
#      'x': 537.5000000000019,
#      'y': 337.5000000000012}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07869.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 199.0000000000007,
#      'width': 267.00000000000114,
#      'x': 915.5000000000033,
#      'y': 279.500000000001}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07868.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 98.00000000000036,
#      'width': 274.00000000000097,
#      'x': 532.0000000000019,
#      'y': 109.0000000000004},
#     {'class': 'rect',
#      'height': 103.00000000000036,
#      'width': 338.00000000000114,
#      'x': 945.0000000000033,
#      'y': 159.50000000000057},
#     {'class': 'rect',
#      'height': 114.0000000000004,
#      'width': 251.00000000000102,
#      'x': 1082.5000000000039,
#      'y': 278.000000000001},
#     {'class': 'rect',
#      'height': 132.00000000000045,
#      'width': 317.00000000000125,
#      'x': 904.5000000000034,
#      'y': 294.00000000000097},
#     {'class': 'rect',
#      'height': 82.00000000000028,
#      'width': 307.00000000000114,
#      'x': 1000.5000000000035,
#      'y': 476.0000000000017}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07863.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 159.0000000000005,
#      'width': 108.00000000000045,
#      'x': 604.0000000000022,
#      'y': 504.5000000000018}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07862.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 112.0000000000004,
#      'width': 153.0000000000005,
#      'x': 473.5000000000017,
#      'y': 457.0000000000016},
#     {'class': 'rect',
#      'height': 64.00000000000023,
#      'width': 104.00000000000037,
#      'x': 194.00000000000068,
#      'y': 443.0000000000016},
#     {'class': 'rect',
#      'height': 157.00000000000057,
#      'width': 75.00000000000028,
#      'x': 143.5000000000005,
#      'y': 564.500000000002}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07858.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 52.000000000000185,
#      'width': 116.00000000000045,
#      'x': 632.0000000000023,
#      'y': 85.00000000000031}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07851.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 186.00000000000068,
#      'width': 388.00000000000136,
#      'x': 723.0000000000026,
#      'y': 237.00000000000085}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07850.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 66.00000000000023,
#      'width': 124.00000000000045,
#      'x': 319.00000000000114,
#      'y': 549.0000000000019}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07836.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 131.00000000000045,
#      'width': 323.0000000000011,
#      'x': 428.5000000000015,
#      'y': 261.5000000000009}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07826.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 65.00000000000026,
#      'width': 101.00000000000034,
#      'x': 347.50000000000125,
#      'y': 207.50000000000074}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07822.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 106.00000000000038,
#      'width': 332.00000000000114,
#      'x': 453.0000000000016,
#      'y': 130.00000000000045},
#     {'class': 'rect',
#      'height': 112.0000000000004,
#      'width': 304.00000000000114,
#      'x': 338.00000000000125,
#      'y': 370.00000000000136}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07814.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 134.00000000000045,
#      'width': 138.0000000000005,
#      'x': 508.0000000000018,
#      'y': 451.0000000000016}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07811.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 181.00000000000065,
#      'width': 374.00000000000136,
#      'x': 823.000000000003,
#      'y': 272.50000000000097}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07810.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 102.0000000000004,
#      'width': 111.0000000000004,
#      'x': 462.5000000000016,
#      'y': 411.0000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07807.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 157.00000000000063,
#      'width': 156.00000000000057,
#      'x': 689.0000000000025,
#      'y': 545.5000000000019}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07802.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 166.00000000000057,
#      'width': 411.0000000000015,
#      'x': 784.5000000000027,
#      'y': 396.0000000000014},
#     {'class': 'rect',
#      'height': 101.00000000000036,
#      'width': 327.00000000000114,
#      'x': 410.5000000000015,
#      'y': 149.50000000000054}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07801.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 50.00000000000023,
#      'width': 170.00000000000063,
#      'x': 544.0000000000019,
#      'y': 505.0000000000018}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07797.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 129.00000000000045,
#      'width': 261.0000000000009,
#      'x': 1016.5000000000036,
#      'y': 268.50000000000097}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07794.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 129.00000000000045,
#      'width': 196.00000000000068,
#      'x': 396.0000000000014,
#      'y': 322.50000000000114}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07789.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 120.00000000000044,
#      'width': 191.00000000000068,
#      'x': 845.500000000003,
#      'y': 89.00000000000031}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07785.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 71.00000000000023,
#      'width': 202.00000000000074,
#      'x': 265.0000000000009,
#      'y': 414.5000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07773.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 85.00000000000028,
#      'width': 91.00000000000034,
#      'x': 816.500000000003,
#      'y': 326.50000000000114},
#     {'class': 'rect',
#      'height': 55.0000000000002,
#      'width': 94.00000000000034,
#      'x': 636.0000000000023,
#      'y': 76.50000000000027}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07772.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 72.00000000000028,
#      'width': 179.00000000000057,
#      'x': 468.50000000000165,
#      'y': 437.0000000000016}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07771.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 179.00000000000065,
#      'width': 83.00000000000034,
#      'x': 626.5000000000023,
#      'y': 337.5000000000012}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07768.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 170.0000000000006,
#      'width': 143.0000000000005,
#      'x': 159.50000000000057,
#      'y': 189.00000000000068},
#     {'class': 'rect',
#      'height': 98.00000000000036,
#      'width': 378.00000000000136,
#      'x': 694.0000000000025,
#      'y': 156.00000000000057}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07767.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 72.00000000000026,
#      'width': 194.00000000000068,
#      'x': 241.00000000000085,
#      'y': 150.0000000000005},
#     {'class': 'rect',
#      'height': 86.0000000000003,
#      'width': 376.00000000000125,
#      'x': 752.0000000000027,
#      'y': 150.00000000000054}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07766.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 127.00000000000045,
#      'width': 121.00000000000045,
#      'x': 696.5000000000025,
#      'y': 416.5000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07763.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 124.00000000000045,
#      'width': 110.00000000000045,
#      'x': 541.0000000000019,
#      'y': 367.0000000000013}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07755.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 89.00000000000031,
#      'width': 372.00000000000136,
#      'x': 745.0000000000026,
#      'y': 146.5000000000005},
#     {'class': 'rect',
#      'height': 67.00000000000024,
#      'width': 196.00000000000068,
#      'x': 243.00000000000085,
#      'y': 148.50000000000054}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07749.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 132.00000000000045,
#      'width': 36.000000000000114,
#      'x': 602.000000000002,
#      'y': 449.0000000000016}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07745.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 101.05823052798263,
#      'width': 112.00620550184749,
#      'x': 692.6699550772146,
#      'y': 405.07507403299724}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07741.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 117.90126894931308,
#      'width': 107.79544589651482,
#      'x': 861.5214152510523,
#      'y': 336.01861650554235},
#     {'class': 'rect',
#      'height': 145.69228234450838,
#      'width': 113.69050934398047,
#      'x': 621.9291937076267,
#      'y': 500.6593170740475},
#     {'class': 'rect',
#      'height': 107.79544589651482,
#      'width': 115.37481318611356,
#      'x': 701.9336262089464,
#      'y': 374.7576048746024}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07740.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 196.22139760849961,
#      'width': 84.21519210665224,
#      'x': 696.4596387220139,
#      'y': 525.9238747060431},
#     {'class': 'rect',
#      'height': 101.05823052798263,
#      'width': 105.26899013331524,
#      'x': 885.5227450014481,
#      'y': 354.5459587690059}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07739.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 232.43393021436003,
#      'width': 160.85101692370574,
#      'x': 386.12665580900045,
#      'y': 468.23646811298636}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07735.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 144.8501304234418,
#      'width': 150.74519387090749,
#      'x': 296.85855217594906,
#      'y': 135.58645929171007}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07732.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 90.95240747518437,
#      'width': 202.95861297703186,
#      'x': 300.2271598602152,
#      'y': 425.28672013859375}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07730.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 116.2169651071801,
#      'width': 88.42595171198491,
#      'x': 769.3057798942681,
#      'y': 398.337858664465}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07727.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 127.16494008104485,
#      'width': 361.283174137538,
#      'x': 845.9416047113216,
#      'y': 442.55083452045744},
#     {'class': 'rect',
#      'height': 97.68962284371659,
#      'width': 275.38367818875275,
#      'x': 384.44235196686736,
#      'y': 157.48240923943968}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07726.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 124.63848431784527,
#      'width': 297.2796281364823,
#      'x': 761.7264126046693,
#      'y': 259.38279168848885},
#     {'class': 'rect',
#      'height': 108.63759781758138,
#      'width': 401.70646634873106,
#      'x': 819.8348951582594,
#      'y': 129.27031988371118},
#     {'class': 'rect',
#      'height': 88.42595171198484,
#      'width': 303.174691583948,
#      'x': 437.07684703352504,
#      'y': 102.32145840958245},
#     {'class': 'rect',
#      'height': 75.79367289598699,
#      'width': 90.11025555411788,
#      'x': 68.63538156692157,
#      'y': 266.96215897808753}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07720.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 28.633165316261795,
#      'width': 176.0097515029031,
#      'x': 853.5209720009203,
#      'y': 384.0212760063341}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07710.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 70.74076136958786,
#      'width': 284.6473493204845,
#      'x': 512.0283680084456,
#      'y': 299.80608389968194}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07709.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 103.58468629118227,
#      'width': 52.213419106124434,
#      'x': 903.6290113043783,
#      'y': 350.7562751242065},
#     {'class': 'rect',
#      'height': 90.11025555411788,
#      'width': 69.05645752745488,
#      'x': 841.3097691454557,
#      'y': 343.17690783460785}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07705.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 42.10759605332612,
#      'width': 62.319242158922634,
#      'x': 955.0002784894363,
#      'y': 214.74873987196318}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07704.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 101.05823052798269,
#      'width': 65.68784984318881,
#      'x': 853.9420479614536,
#      'y': 373.0733010324694}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07701.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 69.05645752745477,
#      'width': 128.00709200211134,
#      'x': 417.7073528489951,
#      'y': 461.4992527444542}],
#    'class': 'image',
#    'filename': 'train/ALB/img_
],
#    'class': 'image',
#    'filename': 'train/ALB/img_07527.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 79.16228058025308,
#      'width': 51.371267185057945,
#      'x': 829.9407182110576,
#      'y': 342.75583187407454}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07522.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 139.79721889704268,
#      'width': 387.3898836906003,
#      'x': 791.6228058025309,
#      'y': 407.6015297961968},
#     {'class': 'rect',
#      'height': 100.21607860691616,
#      'width': 305.70114734714764,
#      'x': 409.7069095988631,
#      'y': 155.37702943677337}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07520.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 91.79455939625092,
#      'width': 354.54595876900584,
#      'x': 494.76425362658176,
#      'y': 240.4343734644921},
#     {'class': 'rect',
#      'height': 112.00620550184746,
#      'width': 274.5415262676863,
#      'x': 532.2400141140421,
#      'y': 132.63892756797725},
#     {'class': 'rect',
#      'height': 298.1217800575489,
#      'width': 281.27874163621834,
#      'x': 818.5716672766596,
#      'y': 300.6482358207484}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07511.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 100.21607860691614,
#      'width': 65.6878498431887,
#      'x': 875.8379979091831,
#      'y': 354.96703472953914}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07492.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 356.23026261113887,
#      'width': 225.69671484582796,
#      'x': 1032.4782552275562,
#      'y': 428.2342518623266}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07491.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 144.85013042344184,
#      'width': 192.01063800316706,
#      'x': 402.54861826979766,
#      'y': 314.96481847887935}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07489.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 112.00620550184746,
#      'width': 322.5441857684781,
#      'x': 432.4450114676592,
#      'y': 115.79588914664681},
#     {'class': 'rect',
#      'height': 180.22051110823574,
#      'width': 235.80253789862627,
#      'x': 1082.165218570481,
#      'y': 286.33165316261756}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07488.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 174.32544766077012,
#      'width': 423.60241629646066,
#      'x': 755.8313491572037,
#      'y': 329.70247709754346},
#     {'class': 'rect',
#      'height': 87.5837997909183,
#      'width': 104.42683821224887,
#      'x': 1221.1202855464571,
#      'y': 606.3493831678961}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07486.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 57.266330632523534,
#      'width': 166.74608037117133,
#      'x': 450.5512777705894,
#      'y': 483.39520269218383}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07479.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 118.74342087037962,
#      'width': 320.0177300052784,
#      'x': 430.33963166499285,
#      'y': 119.1644968309129},
#     {'class': 'rect',
#      'height': 196.2213976084997,
#      'width': 227.38101868796105,
#      'x': 1069.5329397544833,
#      'y': 301.9114637023482}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07477.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 236.64468981969276,
#      'width': 344.4401357162076,
#      'x': 782.7802106313325,
#      'y': 231.17070233276036}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07476.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 47.16050757972522,
#      'width': 133.90215544957704,
#      'x': 299.38500793914864,
#      'y': 446.34051816525675}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07471.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 91.79455939625092,
#      'width': 62.319242158922634,
#      'x': 814.360907671327,
#      'y': 301.9114637023482}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07470.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 154.1138015551736,
#      'width': 332.6500088212763,
#      'x': 921.7352776073086,
#      'y': 674.9847647348176}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07465.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 176.8519034239697,
#      'width': 417.707352848995,
#      'x': 682.9852079849495,
#      'y': 474.97368348151855}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07463.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 57.26633063252348,
#      'width': 98.53177476478311,
#      'x': 344.01905975567433,
#      'y': 421.07596053326114}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07461.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 149.90304194984094,
#      'width': 245.90836095142458,
#      'x': 885.1016690409149,
#      'y': 99.37392668584963}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07459.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 100.21607860691608,
#      'width': 112.84835742291392,
#      'x': 471.6050757972524,
#      'y': 475.3947594420518}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07454.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 129.69139584424443,
#      'width': 181.90481495036875,
#      'x': 870.785086382784,
#      'y': 74.95152097492047}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07452.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 125.48063623891184,
#      'width': 192.01063800316706,
#      'x': 850.5734402771875,
#      'y': 270.7518426228869}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07450.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 92.63671131731743,
#      'width': 39.58114029012654,
#      'x': 639.6143840500237,
#      'y': 187.79987839783445},
#     {'class': 'rect',
#      'height': 88.42595171198485,
#      'width': 39.58114029012654,
#      'x': 611.8233706548284,
#      'y': 169.69361209490424},
#     {'class': 'rect',
#      'height': 85.89949594878527,
#      'width': 37.05468452692696,
#      'x': 576.0319140095012,
#      'y': 182.74696687143532},
#     {'class': 'rect',
#      'height': 27.791013395195236,
#      'width': 39.58114029012654,
#      'x': 617.718434102294,
#      'y': 72.00398925118765},
#     {'class': 'rect',
#      'height': 25.26455763199567,
#      'width': 58.95063447465657,
#      'x': 663.6157138004196,
#      'y': 80.00443250131961},
#     {'class': 'rect',
#      'height': 32.843924921594365,
#      'width': 56.42417871145699,
#      'x': 717.0923607881437,
#      'y': 55.16095082985721}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07449.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 75.79367289598702,
#      'width': 133.0600035285105,
#      'x': 229.90747445116057,
#      'y': 428.6553278228598}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07447.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 108.63759781758142,
#      'width': 137.27076313384316,
#      'x': 491.39564594231575,
#      'y': 463.6046325471205},
#     {'class': 'rect',
#      'height': 187.79987839783445,
#      'width': 66.53000176425526,
#      'x': 152.8505736735738,
#      'y': 571.4000784436354}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07445.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 106.95329397544833,
#      'width': 310.7540588735468,
#      'x': 1049.74236960942,
#      'y': 345.70336359780737},
#     {'class': 'rect',
#      'height': 115.37481318611356,
#      'width': 311.5962107946133,
#      'x': 850.5734402771875,
#      'y': 231.17070233276036},
#     {'class': 'rect',
#      'height': 102.7425343701157,
#      'width': 255.1720320831563,
#      'x': 821.5191990003925,
#      'y': 143.16582658130878}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07444.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 160.00886500263925,
#      'width': 154.1138015551736,
#      'x': 294.33209641274954,
#      'y': 133.90215544957704}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07443.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 161.69316884477226,
#      'width': 320.0177300052785,
#      'x': 955.0002784894363,
#      'y': 267.8043108991541}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07442.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 58.95063447465651,
#      'width': 163.37747268690532,
#      'x': 355.3881106900724,
#      'y': 465.7100123497868}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07441.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 136.42861121277662,
#      'width': 50.52911526399134,
#      'x': 869.1007825406509,
#      'y': 361.283174137538}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07439.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 53.89772294825747,
#      'width': 148.2187381077079,
#      'x': 260.22494360955534,
#      'y': 448.86697392845633}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07437.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 64.00354600105567,
#      'width': 144.00797850237532,
#      'x': 295.1742483338161,
#      'y': 447.18267008632336}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07435.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 169.50354609929144,
#      'width': 87.23404255319178,
#      'x': 686.1702127659603,
#      'y': 432.97872340425704}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07432.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 289.3617021276607,
#      'width': 405.67375886524997,
#      'x': 582.9787234042577,
#      'y': 382.26950354610085},
#     {'class': 'rect',
#      'height': 101.41843971631243,
#      'width': 170.21276595744746,
#      'x': 462.4113475177324,
#      'y': 397.51773049645556}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07424.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 81.00000000000034,
#      'width': 46.00000000000023,
#      'x': 649.0000000000028,
#      'y': 524.5000000000023}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07423.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 175.00000000000074,
#      'width': 190.0000000000008,
#      'x': 706.0000000000032,
#      'y': 536.5000000000024}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07418.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 180.00000000000074,
#      'width': 111.00000000000045,
#      'x': 657.500000000003,
#      'y': 434.00000000000193},
#     {'class': 'rect',
#      'height': 133.00000000000057,
#      'width': 88.00000000000034,
#      'x': 736.0000000000032,
#      'y': 418.5000000000019}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07412.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 68.00000000000034,
#      'width': 163.00000000000074,
#      'x': 415.5000000000018,
#      'y': 449.000000000002}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07406.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 196.00000000000085,
#      'width': 299.00000000000125,
#      'x': 930.5000000000041,
#      'y': 287.00000000000125},
#     {'class': 'rect',
#      'height': 81.00000000000036,
#      'width': 331.00000000000136,
#      'x': 716.5000000000032,
#      'y': 133.5000000000006}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07404.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 120.00000000000053,
#      'width': 358.0000000000016,
#      'x': 694.0000000000031,
#      'y': 128.00000000000057},
#     {'class': 'rect',
#      'height': 145.00000000000063,
#      'width': 326.00000000000136,
#      'x': 384.0000000000017,
#      'y': 188.50000000000082},
#     {'class': 'rect',
#      'height': 125.00000000000057,
#      'width': 339.0000000000015,
#      'x': 722.5000000000032,
#      'y': 646.500000000003}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07398.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 163.0000000000007,
#      'width': 308.0000000000013,
#      'x': 651.0000000000028,
#      'y': 243.50000000000108},
#     {'class': 'rect',
#      'height': 107.00000000000047,
#      'width': 332.0000000000014,
#      'x': 431.00000000000193,
#      'y': 114.50000000000051}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07397.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 60.000000000000284,
#      'width': 158.0000000000007,
#      'x': 252.00000000000114,
#      'y': 415.0000000000018}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07396.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 160.00000000000074,
#      'width': 153.00000000000068,
#      'x': 295.5000000000013,
#      'y': 135.0000000000006}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07394.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 171.0000000000008,
#      'width': 99.00000000000045,
#      'x': 845.5000000000038,
#      'y': 686.500000000003}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07390.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 107.00000000000048,
#      'width': 348.0000000000015,
#      'x': 553.0000000000025,
#      'y': 148.50000000000068}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07384.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 157.00000000000068,
#      'width': 384.0000000000017,
#      'x': 722.0000000000032,
#      'y': 260.50000000000114}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07381.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 122.00000000000054,
#      'width': 328.0000000000014,
#      'x': 429.00000000000193,
#      'y': 120.00000000000053},
#     {'class': 'rect',
#      'height': 125.00000000000057,
#      'width': 340.00000000000153,
#      'x': 668.000000000003,
#      'y': 217.50000000000097}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07380.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 91.0000000000004,
#      'width': 160.00000000000068,
#      'x': 388.0000000000017,
#      'y': 221.500000000001}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07377.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 158.00000000000068,
#      'width': 61.00000000000023,
#      'x': 493.50000000000216,
#      'y': 422.0000000000019},
#     {'class': 'rect',
#      'height': 150.00000000000068,
#      'width': 53.00000000000024,
#      'x': 144.50000000000065,
#      'y': 567.0000000000025}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07374.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 193.0000000000009,
#      'width': 235.00000000000105,
#      'x': 176.5000000000008,
#      'y': 456.50000000000205}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07366.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 134.00000000000057,
#      'width': 52.00000000000023,
#      'x': 412.0000000000018,
#      'y': 452.000000000002}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07358.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 113.00000000000045,
#      'width': 164.0000000000008,
#      'x': 836.0000000000036,
#      'y': 396.50000000000176}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07349.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 147.00000000000065,
#      'width': 355.0000000000016,
#      'x': 694.5000000000031,
#      'y': 145.50000000000063},
#     {'class': 'rect',
#      'height': 146.00000000000063,
#      'width': 298.0000000000013,
#      'x': 387.0000000000017,
#      'y': 186.0000000000008}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07335.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 137.00000000000063,
#      'width': 183.0000000000008,
#      'x': 704.5000000000032,
#      'y': 431.50000000000193}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07328.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 122.00000000000057,
#      'width': 51.00000000000023,
#      'x': 797.5000000000035,
#      'y': 317.0000000000014}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07316.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 150.00000000000068,
#      'width': 64.00000000000028,
#      'x': 402.0000000000018,
#      'y': 460.00000000000205}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07307.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 449.00000000000193,
#      'width': 151.00000000000068,
#      'x': 337.5000000000015,
#      'y': 402.50000000000176}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07306.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 167.00000000000074,
#      'width': 97.00000000000043,
#      'x': 275.5000000000012,
#      'y': 351.5000000000016}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07300.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 138.00000000000057,
#      'width': 97.00000000000034,
#      'x': 857.5000000000039,
#      'y': 421.0000000000019},
#     {'class': 'rect',
#      'height': 130.00000000000057,
#      'width': 84.00000000000034,
#      'x': 798.0000000000036,
#      'y': 394.00000000000176},
#     {'class': 'rect',
#      'height': 134.00000000000063,
#      'width': 90.00000000000034,
#      'x': 726.0000000000032,
#      'y': 378.0000000000017},
#     {'class': 'rect',
#      'height': 181.0000000000008,
#      'width': 147.00000000000068,
#      'x': 610.5000000000027,
#      'y': 495.5000000000022},
#     {'class': 'rect',
#      'height': 156.00000000000063,
#      'width': 115.00000000000045,
#      'x': 659.500000000003,
#      'y': 520.0000000000023},
#     {'class': 'rect',
#      'height': 229.00000000000097,
#      'width': 89.00000000000034,
#      'x': 729.5000000000032,
#      'y': 561.5000000000025},
#     {'class': 'rect',
#      'height': 150.00000000000068,
#      'width': 195.0000000000009,
#      'x': 588.5000000000026,
#      'y': 648.0000000000028}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07299.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 276.00000000000125,
#      'width': 267.0000000000012,
#      'x': 479.50000000000216,
#      'y': 284.00000000000125}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07298.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 111.00000000000045,
#      'width': 318.0000000000015,
#      'x': 953.0000000000043,
#      'y': 257.50000000000114}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07296.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 129.00000000000057,
#      'width': 394.0000000000018,
#      'x': 772.0000000000034,
#      'y': 253.50000000000114},
#     {'class': 'rect',
#      'height': 152.00000000000068,
#      'width': 371.0000000000017,
#      'x': 837.5000000000036,
#      'y': 430.00000000000193},
#     {'class': 'rect',
#      'height': 137.00000000000063,
#      'width': 324.0000000000015,
#      'x': 517.0000000000023,
#      'y': 337.5000000000015}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07291.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 120.00000000000054,
#      'width': 105.00000000000045,
#      'x': 493.50000000000216,
#      'y': 94.00000000000043}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07285.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 194.0000000000009,
#      'width': 166.0000000000008,
#      'x': 752.0000000000034,
#      'y': 557.0000000000025},
#     {'class': 'rect',
#      'height': 91.0000000000004,
#      'width': 100.00000000000045,
#      'x': 826.0000000000036,
#      'y': 377.5000000000017}],
#    'class': 'image',
#    'filename': 'train/ALB/img_07280.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 411.0000000000019,
#      'width': 118.00000000000054,
#      'x': 99.00000000000045,
#      'y': 399.5000000000018},
#     {'class': 'rect',
#      'height': 152.00000000000065,
#      'width': 86.0000000000004,
#      'x': 211.00000000000094,
#      'y': 246.00000000000108}],
# ...
#      'x': 618.500000000002,
#      'y': 582.5000000000019}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00680.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 140.00000000000045,
#      'width': 220.00000000000074,
#      'x': 280.0000000000009,
#      'y': 403.00000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00677.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 204.00000000000068,
#      'width': 246.0000000000008,
#      'x': 772.0000000000025,
#      'y': 545.0000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00647.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 305.000000000001,
#      'width': 300.000000000001,
#      'x': 174.00000000000057,
#      'y': 430.5000000000014}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00641.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 271.0000000000009,
#      'width': 239.0000000000008,
#      'x': 868.500000000003,
#      'y': 683.5000000000023}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00573.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 258.0000000000009,
#      'width': 225.00000000000068,
#      'x': 618.500000000002,
#      'y': 137.00000000000048}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00572.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 107.00000000000034,
#      'width': 246.0000000000008,
#      'x': 223.00000000000074,
#      'y': 396.5000000000013},
#     {'class': 'rect',
#      'height': 206.00000000000068,
#      'width': 453.00000000000153,
#      'x': 613.500000000002,
#      'y': 155.0000000000005}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00566.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 123.00000000000034,
#      'width': 240.0000000000008,
#      'x': 504.00000000000165,
#      'y': 463.50000000000153},
#     {'class': 'rect',
#      'height': 140.00000000000045,
#      'width': 72.00000000000026,
#      'x': 157.0000000000005,
#      'y': 603.000000000002}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00540.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 172.00000000000057,
#      'width': 270.00000000000097,
#      'x': 465.0000000000016,
#      'y': 461.00000000000153}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00539.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 229.00000000000074,
#      'width': 348.00000000000114,
#      'x': 378.00000000000125,
#      'y': 316.500000000001}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00536.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 111.00000000000034,
#      'width': 189.00000000000063,
#      'x': 459.5000000000015,
#      'y': 445.5000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00535.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 116.0000000000004,
#      'width': 109.00000000000034,
#      'x': 669.5000000000023,
#      'y': 415.00000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00522.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 308.0000000000011,
#      'width': 428.0000000000015,
#      'x': 856.000000000003,
#      'y': 656.0000000000022}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00506.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 291.000000000001,
#      'width': 488.0000000000016,
#      'x': 860.0000000000028,
#      'y': 342.50000000000114},
#     {'class': 'rect',
#      'height': 149.0000000000005,
#      'width': 280.0000000000009,
#      'x': 720.0000000000024,
#      'y': 156.5000000000005}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00501.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 78.00000000000023,
#      'width': 184.00000000000057,
#      'x': 535.0000000000018,
#      'y': 481.0000000000016}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00477.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 160.00000000000057,
#      'width': 206.00000000000063,
#      'x': 453.0000000000015,
#      'y': 459.00000000000153}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00470.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 82.00000000000023,
#      'width': 142.00000000000045,
#      'x': 336.00000000000114,
#      'y': 445.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00440.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 173.0000000000006,
#      'width': 392.00000000000136,
#      'x': 407.00000000000136,
#      'y': 335.50000000000114}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00439.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 161.0000000000005,
#      'width': 179.00000000000057,
#      'x': 806.5000000000027,
#      'y': 399.50000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00437.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 62.00000000000023,
#      'width': 139.00000000000045,
#      'x': 344.50000000000114,
#      'y': 443.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00436.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 137.00000000000045,
#      'width': 75.00000000000026,
#      'x': 157.5000000000005,
#      'y': 600.500000000002},
#     {'class': 'rect',
#      'height': 121.00000000000034,
#      'width': 229.00000000000074,
#      'x': 504.5000000000017,
#      'y': 464.50000000000153}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00420.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 215.00000000000074,
#      'width': 360.00000000000125,
#      'x': 661.0000000000023,
#      'y': 531.5000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00404.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 337.0000000000011,
#      'width': 156.00000000000057,
#      'x': 602.000000000002,
#      'y': 558.5000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00395.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 167.00000000000057,
#      'width': 486.00000000000165,
#      'x': 427.0000000000015,
#      'y': 409.50000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00378.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 74.00000000000023,
#      'width': 162.00000000000057,
#      'x': 394.0000000000013,
#      'y': 441.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00372.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 286.0000000000009,
#      'width': 557.0000000000019,
#      'x': 869.500000000003,
#      'y': 324.0000000000011},
#     {'class': 'rect',
#      'height': 146.00000000000048,
#      'width': 317.000000000001,
#      'x': 698.5000000000023,
#      'y': 150.0000000000005}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00370.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 334.0000000000012,
#      'width': 294.00000000000097,
#      'x': 578.0000000000019,
#      'y': 568.0000000000019}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00362.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 76.00000000000023,
#      'width': 190.00000000000057,
#      'x': 532.0000000000018,
#      'y': 486.0000000000016}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00333.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 164.00000000000057,
#      'width': 188.00000000000057,
#      'x': 1074.0000000000036,
#      'y': 185.00000000000063}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00313.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 198.00000000000068,
#      'width': 664.0000000000023,
#      'x': 940.0000000000032,
#      'y': 647.0000000000022}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00312.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 276.0000000000009,
#      'width': 363.00000000000114,
#      'x': 722.5000000000024,
#      'y': 609.000000000002}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00298.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 88.00000000000028,
#      'width': 248.00000000000085,
#      'x': 347.00000000000114,
#      'y': 453.0000000000015},
#     {'class': 'rect',
#      'height': 163.00000000000057,
#      'width': 89.0000000000003,
#      'x': 142.50000000000048,
#      'y': 566.5000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00287.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 106.0000000000004,
#      'width': 205.00000000000068,
#      'x': 359.5000000000012,
#      'y': 434.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00286.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 314.000000000001,
#      'width': 506.0000000000016,
#      'x': 857.0000000000028,
#      'y': 344.00000000000114},
#     {'class': 'rect',
#      'height': 156.0000000000005,
#      'width': 276.0000000000009,
#      'x': 718.0000000000024,
#      'y': 154.0000000000005}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00284.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 172.00000000000057,
#      'width': 463.0000000000016,
#      'x': 434.5000000000015,
#      'y': 403.00000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00279.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 176.0000000000006,
#      'width': 395.0000000000013,
#      'x': 416.50000000000136,
#      'y': 332.00000000000114}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00276.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 277.0000000000009,
#      'width': 204.00000000000074,
#      'x': 535.0000000000018,
#      'y': 517.5000000000017}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00253.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 160.0000000000005,
#      'width': 198.00000000000068,
#      'x': 814.0000000000027,
#      'y': 397.00000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00250.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 321.0000000000011,
#      'width': 144.00000000000045,
#      'x': 582.0000000000019,
#      'y': 548.5000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00238.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 152.0000000000005,
#      'width': 62.0000000000002,
#      'x': 143.00000000000045,
#      'y': 567.0000000000019},
#     {'class': 'rect',
#      'height': 70.00000000000023,
#      'width': 197.00000000000065,
#      'x': 273.5000000000009,
#      'y': 440.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00222.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 277.0000000000009,
#      'width': 415.00000000000136,
#      'x': 970.5000000000032,
#      'y': 262.50000000000085},
#     {'class': 'rect',
#      'height': 166.00000000000057,
#      'width': 274.0000000000009,
#      'x': 703.0000000000024,
#      'y': 164.00000000000057}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00221.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 72.00000000000023,
#      'width': 96.00000000000034,
#      'x': 439.0000000000015,
#      'y': 441.0000000000015},
#     {'class': 'rect',
#      'height': 104.00000000000034,
#      'width': 45.000000000000156,
#      'x': 86.50000000000028,
#      'y': 595.000000000002}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00218.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 264.0000000000009,
#      'width': 420.0000000000014,
#      'x': 263.0000000000009,
#      'y': 339.00000000000114}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00217.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 179.0000000000006,
#      'width': 359.0000000000012,
#      'x': 368.50000000000125,
#      'y': 133.50000000000045},
#     {'class': 'rect',
#      'height': 120.00000000000041,
#      'width': 268.0000000000009,
#      'x': 582.0000000000019,
#      'y': 158.00000000000054},
#     {'class': 'rect',
#      'height': 83.00000000000028,
#      'width': 303.0000000000009,
#      'x': 750.5000000000025,
#      'y': 119.5000000000004},
#     {'class': 'rect',
#      'height': 199.00000000000068,
#      'width': 375.00000000000125,
#      'x': 974.5000000000032,
#      'y': 222.50000000000074}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00214.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 237.00000000000085,
#      'width': 124.00000000000045,
#      'x': 891.000000000003,
#      'y': 516.5000000000017}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00194.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 140.00000000000048,
#      'width': 399.0000000000013,
#      'x': 209.50000000000068,
#      'y': 316.0000000000011}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00184.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 150.0000000000005,
#      'width': 283.0000000000009,
#      'x': 899.500000000003,
#      'y': 417.00000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00139.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 143.00000000000045,
#      'width': 174.00000000000068,
#      'x': 972.0000000000033,
#      'y': 515.5000000000017}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00137.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 146.0000000000005,
#      'width': 375.00000000000125,
#      'x': 214.5000000000007,
#      'y': 330.00000000000114}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00118.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 246.0000000000008,
#      'width': 313.0000000000011,
#      'x': 614.500000000002,
#      'y': 573.0000000000018}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00116.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 236.0000000000008,
#      'width': 337.00000000000125,
#      'x': 966.5000000000032,
#      'y': 243.0000000000008}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00114.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 175.00000000000057,
#      'width': 164.00000000000057,
#      'x': 849.0000000000027,
#      'y': 405.50000000000136}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00093.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 77.00000000000023,
#      'width': 180.00000000000057,
#      'x': 535.0000000000018,
#      'y': 484.5000000000016}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00092.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 293.0000000000009,
#      'width': 230.0000000000008,
#      'x': 872.000000000003,
#      'y': 686.5000000000023}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00069.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 180.0000000000006,
#      'width': 421.00000000000136,
#      'x': 808.5000000000027,
#      'y': 220.00000000000074},
#     {'class': 'rect',
#      'height': 103.00000000000034,
#      'width': 330.0000000000011,
#      'x': 491.0000000000016,
#      'y': 119.5000000000004}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00061.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 57.00000000000017,
#      'width': 167.00000000000057,
#      'x': 485.50000000000165,
#      'y': 369.50000000000125}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00052.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 143.0000000000005,
#      'width': 142.00000000000045,
#      'x': 545.0000000000018,
#      'y': 211.5000000000007}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00047.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 136.00000000000045,
#      'width': 168.00000000000054,
#      'x': 317.000000000001,
#      'y': 440.0000000000015}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00023.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 240.00000000000085,
#      'width': 125.00000000000045,
#      'x': 888.500000000003,
#      'y': 512.0000000000017}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00021.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 166.00000000000057,
#      'width': 210.00000000000074,
#      'x': 465.0000000000016,
#      'y': 395.0000000000013}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00014.jpg'},
#   {'annotations': [{'class': 'rect',
#      'height': 269.00000000000097,
#      'width': 405.00000000000136,
#      'x': 748.5000000000025,
#      'y': 600.500000000002}],
#    'class': 'image',
#    'filename': 'train/YFT/img_00004.jpg'}]}

# %%
counts = pd.DataFrame(
    [(k, len(v)) for k, v in boxes.items()],
    columns=['class', 'count'])

fish_classes = counts['class'].values
print(fish_classes)
counts
# Out:
# ['dol' 'yft' 'shark' 'other' 'lag' 'bet' 'alb']
#    class  count
# 0    dol    117
# 1    yft    734
# 2  shark    176
# 3  other    299
# 4    lag     67
# 5    bet    200
# 6    alb   1719

# %%
from matplotlib import pyplot as plt


annotation = boxes['lag'][0]
img = draw_boxes(annotation)

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(img)
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %%
annotations = sum([box['annotations']
                   for box in sum(boxes.values(), [])], [])

widths = [rect['width'] for rect in annotations]
heights = [rect['height'] for rect in annotations]

plt.hist(widths)
plt.hist(heights);

# %%
from tensorflow.keras.applications import vgg16

IMG_HEIGHT = 750
IMG_WIDTH = 1200

features = vgg16.VGG16(weights='imagenet',
                       include_top=False,
                       input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# дообучаем последние 5 слоев
for layer in features.layers[:-5]:
    layer.trainable = False
    
feature_tensor = features.layers[-1].output
print(feature_tensor.shape)
# Out:
# (None, 23, 37, 512)

# %%
FEATURE_SHAPE = (feature_tensor.shape[1],
                 feature_tensor.shape[2])

GRID_STEP_H = IMG_HEIGHT / FEATURE_SHAPE[0]
GRID_STEP_W = IMG_WIDTH / FEATURE_SHAPE[1]

ANCHOR_WIDTH = 150.
ANCHOR_HEIGHT = 150. 

# сетка якорей, размер определяется соотношением 
# размера входного изображения и размером тензора признаков
ANCHOR_CENTERS = np.mgrid[GRID_STEP_H/2:IMG_HEIGHT:GRID_STEP_H,
                          GRID_STEP_W/2:IMG_WIDTH:GRID_STEP_W]

# %%
def iou(rect, x_scale, y_scale, anchor_x, anchor_y,
        anchor_w=ANCHOR_WIDTH, anchor_h=ANCHOR_HEIGHT):
    
    rect_x1 = (rect['x'] - rect['width'] / 2) * x_scale
    rect_x2 = (rect['x'] + rect['width'] / 2) * x_scale
    
    rect_y1 = (rect['y'] - rect['height'] / 2) * y_scale
    rect_y2 = (rect['y'] + rect['height'] / 2) * y_scale
    
    anch_x1, anch_x2 = anchor_x - anchor_w / 2, anchor_x + anchor_w / 2
    anch_y1, anch_y2 = anchor_y - anchor_h / 2, anchor_y + anchor_h / 2
    
    dx = (min(rect_x2, anch_x2) - max(rect_x1, anch_x1))
    dy = (min(rect_y2, anch_y2) - max(rect_y1, anch_y1))
    
    intersection = dx * dy if (dx > 0 and dy > 0) else 0.
    
    anch_square = (anch_x2 - anch_x1) * (anch_y2 - anch_y1)
    rect_square = (rect_x2 - rect_x1) * (rect_y2 - rect_y1)
    union = anch_square + rect_square - intersection
    
    return intersection / union

def encode_anchors(annotation, img_shape, iou_thr=0.5):
    encoded = np.zeros(shape=(FEATURE_SHAPE[0],
                              FEATURE_SHAPE[1], 11), dtype=np.float32)
    x_scale = 1. * IMG_WIDTH / img_shape[1]
    y_scale = 1. * IMG_HEIGHT / img_shape[0]
    for rect in annotation['annotations']:
        scores = []
        label = fish_classes == rect['class']
                
        for row in range(FEATURE_SHAPE[0]):
            for col in range(FEATURE_SHAPE[1]):
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                score = iou(rect, x_scale, y_scale, anchor_x, anchor_y)
                scores.append((score, anchor_x, anchor_y, row, col))
        
        scores = sorted(scores, reverse=True)
        if scores[0][0] < iou_thr:
            scores = [scores[0]]  # default anchor
        else:
            scores = [e for e in scores if e[0] > iou_thr]
            
        for score, anchor_x, anchor_y, row, col in scores:
            dx = (anchor_x - rect['x'] * x_scale) / ANCHOR_WIDTH
            dy = (anchor_y - rect['y'] * y_scale) / ANCHOR_HEIGHT
            dw = (ANCHOR_WIDTH - rect['width'] * x_scale) / ANCHOR_WIDTH
            dh = (ANCHOR_HEIGHT - rect['height'] * y_scale) / ANCHOR_HEIGHT
            encoded[row, col] = np.array([*label, 1., dx, dy, dw, dh])

    return encoded

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))


def decode_prediction(prediction, conf_thr=0.1):
    rectangles = []
    for row in range(FEATURE_SHAPE[0]):
        for col in range(FEATURE_SHAPE[1]):
            
            label = np.empty(6)
            
            label[0], label[1], label[2], label[3], label[4], label[5], conf, dx, dy, dw, dh = prediction[row, col]
            conf = _sigmoid(conf)
            label = softmax(label)

            if conf > conf_thr:
                anchor_x = ANCHOR_CENTERS[1, row, col]
                anchor_y = ANCHOR_CENTERS[0, row, col]
                rectangles.append({'x': anchor_x - dx * ANCHOR_WIDTH,
                                   'y': anchor_y - dy * ANCHOR_HEIGHT,
                                   'width': ANCHOR_WIDTH - dw * ANCHOR_WIDTH,
                                   'height': ANCHOR_HEIGHT - dh * ANCHOR_HEIGHT,
                                   'conf': conf,
                                   'label': np.argmax(_sigmoid(label)),
                                   'labels': label })
    return rectangles

def non_max_suppression(rectangles, max_output_size, iou_threshold=0.5):
    if not rectangles:
        return rectangles
    
    boxes = [[r['y'],
              r['x'],
              r['y'] + r['height'],
              r['x'] + r['width']] for r in rectangles]
    scores = [r['conf'] for r in rectangles]
    indices = tf.image.non_max_suppression(np.array(boxes),
                                           np.array(scores),
                                           max_output_size,
                                           iou_threshold)
    
    return [rectangles[i] for i in indices]

# %%
annotation = boxes['other'][0]

encoded = encode_anchors(annotation,
                         img_shape=(IMG_HEIGHT, IMG_WIDTH),
                         iou_thr=0.5)

decoded = decode_prediction(encoded, conf_thr=0.7)
decoded = sorted(decoded, key = lambda e: -e['conf'])

plt.figure(figsize=(6, 6), dpi=120)
plt.imshow(draw_boxes(annotation, decoded))
plt.title('{} {}x{}'.format(
    annotation['filename'], img.shape[0], img.shape[1]));

# %%
K = tf.keras.backend

def confidence_loss(y_true, y_pred):
    conf_loss = K.binary_crossentropy(y_true[..., 6], 
                                      y_pred[..., 6],
                                      from_logits=True)
    return conf_loss

def smooth_l1(y_true, y_pred):
    abs_loss = K.abs(y_true[..., -4:] - y_pred[..., -4:])
    square_loss = 0.5 * K.square(y_true[..., -4:] - y_pred[..., -4:])
    mask = K.cast(K.greater(abs_loss, 1.), 'float32')
    total_loss = (abs_loss - 0.5) * mask + 0.5 * square_loss * (1. - mask)
    return K.sum(total_loss, axis=-1)

def class_loss(y_true, y_pred):
    y_true = y_true[..., :6]
    y_pred = y_pred[..., :6]
    cross_entropy = tf.keras.losses.CategoricalCrossentropy(from_logits=True)   
    return cross_entropy(y_true, y_pred)


def total_loss(y_true, y_pred, neg_pos_ratio=3):
    batch_size = K.shape(y_true)[0]
    
    y_true = K.reshape(y_true, (batch_size, -1, 11))
    y_pred = K.reshape(y_pred, (batch_size, -1, 11))
    
    # TODO: добавьте функцию потерь для классификации детекции
    classification_loss = class_loss(y_true, y_pred)

    # confidence loss
    conf_loss = confidence_loss(y_true, y_pred)
    
    # smooth l1 loss
    loc_loss = smooth_l1(y_true, y_pred)
    
    # positive examples loss
    pos_conf_loss = K.sum(conf_loss * y_true[..., 6], axis=-1)
    pos_class_loss = K.sum(classification_loss * y_true[..., 6], axis=-1)
    pos_loc_loss = K.sum(loc_loss * y_true[..., 6], axis=-1)

    
    
    # negative examples loss
    anchors = K.shape(y_true)[1]
    num_pos = K.sum(y_true[..., 6], axis=-1)
    num_pos_avg = K.mean(num_pos)
    num_neg = K.min([neg_pos_ratio * (num_pos_avg) + 1., K.cast(anchors, 'float32')])
    
    # hard negative mining
    neg_conf_loss, _ = tf.nn.top_k(conf_loss * (1. - y_true[..., 6]),
                                   k=K.cast(num_neg, 'int32'))

    neg_conf_loss = K.sum(neg_conf_loss, axis=-1)
    
    # total conf loss
    total_conf_loss = (neg_conf_loss + pos_conf_loss) / (num_neg + num_pos + 1e-32)
    classification_loss = pos_class_loss / (num_pos + 1e-32)
    loc_loss = pos_loc_loss / (num_pos + 1e-32)
    
    return total_conf_loss + 0.5 * loc_loss + classification_loss

# %%
from random import shuffle

def load_img(path, target_size=(IMG_WIDTH, IMG_HEIGHT)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)[...,::-1]
    img_shape = img.shape
    img_resized = cv2.resize(img, target_size)
    return img_shape, tf.keras.applications.resnet_v2.preprocess_input(img_resized.astype(np.float32))

def data_generator(boxes, batch_size=5):
    boxes = sum(boxes.values(), [])
    while True:
        shuffle(boxes)
        for i in range(len(boxes)//batch_size):
            X, y = [], []
            for j in range(i*batch_size,(i+1)*batch_size):
                img_shape, img = load_img(boxes[j]['filename'])
                # TODO: добавьте one-hot encoding в разметку для классов
                y.append(encode_anchors(boxes[j], img_shape))
                X.append(img)
            yield np.array(X), np.array(y)

# %%
output = tf.keras.layers.BatchNormalization()(feature_tensor)

# TODO: добавьте выходы для классификации детекции
output = tf.keras.layers.Conv2D(12,
                                kernel_size=(1, 1), 
                                activation='linear',
                                kernel_regularizer='l2')(output)

model = tf.keras.models.Model(inputs=features.inputs, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 750, 1200, 3)]    0
#
#  block1_conv1 (Conv2D)       (None, 750, 1200, 64)     1792
#
#  block1_conv2 (Conv2D)       (None, 750, 1200, 64)     36928
#
#  block1_pool (MaxPooling2D)  (None, 375, 600, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 375, 600, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 375, 600, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 187, 300, 128)     0
#
#  block3_conv1 (Conv2D)       (None, 187, 300, 256)     295168
#
#  block3_conv2 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_conv3 (Conv2D)       (None, 187, 300, 256)     590080
#
#  block3_pool (MaxPooling2D)  (None, 93, 150, 256)      0
#
#  block4_conv1 (Conv2D)       (None, 93, 150, 512)      1180160
#
#  block4_conv2 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_conv3 (Conv2D)       (None, 93, 150, 512)      2359808
#
#  block4_pool (MaxPooling2D)  (None, 46, 75, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 46, 75, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 23, 37, 512)       0
#
#  batch_normalization_2 (Batc  (None, 23, 37, 512)      2048
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 23, 37, 12)        6156
#
# =================================================================
# Total params: 14,722,892
# Trainable params: 7,086,604
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %%
batch_size = 5
steps_per_epoch = sum(map(len, boxes.values()), 0) / batch_size

gen = data_generator(boxes, batch_size=batch_size)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'fishdetector.hdf5',
    monitor='loss',
    verbose=1,  
    save_best_only=True, 
    save_weights_only=False,
    mode='auto',
    save_freq=10)

adam = tf.keras.optimizers.Adam(lr=3e-4, decay=1e-6)
model.compile(optimizer=adam, 
              loss=total_loss,
              metrics=[confidence_loss])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.fit(gen, 
          steps_per_epoch=steps_per_epoch,
          epochs=10,
          callbacks=[checkpoint])
# Out:
# Epoch 1/10
#   9/662 [..............................] - ETA: 6:24 - loss: 1.7598 - confidence_loss: 0.7038
# Epoch 1: loss improved from inf to 1.69493, saving model to fishdetector.hdf5
#  19/662 [..............................] - ETA: 6:30 - loss: 1.4148 - confidence_loss: 0.6926
# Epoch 1: loss improved from 1.69493 to 1.39280, saving model to fishdetector.hdf5
#  29/662 [>.............................] - ETA: 6:28 - loss: 1.2654 - confidence_loss: 0.6788
# Epoch 1: loss improved from 1.39280 to 1.25462, saving model to fishdetector.hdf5
#  39/662 [>.............................] - ETA: 6:25 - loss: 1.1739 - confidence_loss: 0.6629
# Epoch 1: loss improved from 1.25462 to 1.16709, saving model to fishdetector.hdf5
#  49/662 [=>............................] - ETA: 6:21 - loss: 1.1229 - confidence_loss: 0.6477
# Epoch 1: loss improved from 1.16709 to 1.11669, saving model to fishdetector.hdf5
#  59/662 [=>............................] - ETA: 6:16 - loss: 1.0750 - confidence_loss: 0.6323
# Epoch 1: loss improved from 1.11669 to 1.07257, saving model to fishdetector.hdf5
#  69/662 [==>...........................] - ETA: 6:11 - loss: 1.0400 - confidence_loss: 0.6170
# Epoch 1: loss improved from 1.07257 to 1.03643, saving model to fishdetector.hdf5
#  79/662 [==>...........................] - ETA: 6:06 - loss: 1.0160 - confidence_loss: 0.6013
# Epoch 1: loss improved from 1.03643 to 1.01341, saving model to fishdetector.hdf5
#  89/662 [===>..........................] - ETA: 6:00 - loss: 0.9945 - confidence_loss: 0.5851
# Epoch 1: loss improved from 1.01341 to 0.99229, saving model to fishdetector.hdf5
#  99/662 [===>..........................] - ETA: 5:55 - loss: 0.9734 - confidence_loss: 0.5684
# Epoch 1: loss improved from 0.99229 to 0.97151, saving model to fishdetector.hdf5
# 109/662 [===>..........................] - ETA: 5:50 - loss: 0.9587 - confidence_loss: 0.5513
# Epoch 1: loss improved from 0.97151 to 0.95685, saving model to fishdetector.hdf5
# 119/662 [====>.........................] - ETA: 5:44 - loss: 0.9452 - confidence_loss: 0.5341
# Epoch 1: loss improved from 0.95685 to 0.94457, saving model to fishdetector.hdf5
# 129/662 [====>.........................] - ETA: 5:39 - loss: 0.9356 - confidence_loss: 0.5169
# Epoch 1: loss improved from 0.94457 to 0.93432, saving model to fishdetector.hdf5
# 139/662 [=====>........................] - ETA: 5:33 - loss: 0.9239 - confidence_loss: 0.4998
# Epoch 1: loss improved from 0.93432 to 0.92369, saving model to fishdetector.hdf5
# 149/662 [=====>........................] - ETA: 5:28 - loss: 0.9152 - confidence_loss: 0.4830
# Epoch 1: loss improved from 0.92369 to 0.91419, saving model to fishdetector.hdf5
# 159/662 [======>.......................] - ETA: 5:22 - loss: 0.9075 - confidence_loss: 0.4665
# Epoch 1: loss improved from 0.91419 to 0.90637, saving model to fishdetector.hdf5
# 169/662 [======>.......................] - ETA: 5:17 - loss: 0.9007 - confidence_loss: 0.4508
# Epoch 1: loss improved from 0.90637 to 0.89990, saving model to fishdetector.hdf5
# 179/662 [=======>......................] - ETA: 5:11 - loss: 0.8943 - confidence_loss: 0.4355
# Epoch 1: loss improved from 0.89990 to 0.89348, saving model to fishdetector.hdf5
# 189/662 [=======>......................] - ETA: 5:05 - loss: 0.8896 - confidence_loss: 0.4209
# Epoch 1: loss improved from 0.89348 to 0.88914, saving model to fishdetector.hdf5
# 199/662 [========>.....................] - ETA: 4:59 - loss: 0.8884 - confidence_loss: 0.4071
# Epoch 1: loss improved from 0.88914 to 0.88802, saving model to fishdetector.hdf5
# 209/662 [========>.....................] - ETA: 4:53 - loss: 0.8879 - confidence_loss: 0.3939
# Epoch 1: loss did not improve from 0.88802
# 219/662 [========>.....................] - ETA: 4:46 - loss: 0.8888 - confidence_loss: 0.3814
# Epoch 1: loss did not improve from 0.88802
# 229/662 [=========>....................] - ETA: 4:40 - loss: 0.8894 - confidence_loss: 0.3696
# Epoch 1: loss did not improve from 0.88802
# 239/662 [=========>....................] - ETA: 4:33 - loss: 0.8917 - confidence_loss: 0.3585
# Epoch 1: loss did not improve from 0.88802
# 249/662 [==========>...................] - ETA: 4:27 - loss: 0.8949 - confidence_loss: 0.3481
# Epoch 1: loss did not improve from 0.88802
# 259/662 [==========>...................] - ETA: 4:20 - loss: 0.8978 - confidence_loss: 0.3382
# Epoch 1: loss did not improve from 0.88802
# 269/662 [===========>..................] - ETA: 4:14 - loss: 0.9020 - confidence_loss: 0.3289
# Epoch 1: loss did not improve from 0.88802
# 279/662 [===========>..................] - ETA: 4:07 - loss: 0.9079 - confidence_loss: 0.3200
# Epoch 2: loss did not improve from 0.88802
#  76/662 [==>...........................] - ETA: 6:27 - loss: 4.1862 - confidence_loss: 0.0298
# Epoch 2: loss did not improve from 0.88802
#  86/662 [==>...........................] - ETA: 6:20 - loss: 4.2435 - confidence_loss: 0.0293
# Epoch 2: loss did not improve from 0.88802
#  96/662 [===>..........................] - ETA: 6:13 - loss: 4.3001 - confidence_loss: 0.0292
# Epoch 2: loss did not improve from 0.88802
# 106/662 [===>..........................] - ETA: 6:07 - loss: 4.3616 - confidence_loss: 0.0290
# Epoch 2: loss did not improve from 0.88802
# 116/662 [====>.........................] - ETA: 6:00 - loss: 4.4239 - confidence_loss: 0.0289
# Epoch 2: loss did not improve from 0.88802
# 126/662 [====>.........................] - ETA: 5:53 - loss: 4.4827 - confidence_loss: 0.0287
# Epoch 2: loss did not improve from 0.88802
# 136/662 [=====>........................] - ETA: 5:47 - loss: 4.5429 - confidence_loss: 0.0284
# Epoch 2: loss did not improve from 0.88802
# 146/662 [=====>........................] - ETA: 5:40 - loss: 4.6035 - confidence_loss: 0.0282
# Epoch 2: loss did not improve from 0.88802
# 156/662 [======>.......................] - ETA: 5:33 - loss: 4.6667 - confidence_loss: 0.0280
# Epoch 2: loss did not improve from 0.88802
# 166/662 [======>.......................] - ETA: 5:27 - loss: 4.7256 - confidence_loss: 0.0277
# Epoch 2: loss did not improve from 0.88802
# 176/662 [======>.......................] - ETA: 5:20 - loss: 4.7900 - confidence_loss: 0.0276
# Epoch 2: loss did not improve from 0.88802
# 186/662 [=======>......................] - ETA: 5:13 - loss: 4.8506 - confidence_loss: 0.0275
# Epoch 2: loss did not improve from 0.88802
# 196/662 [=======>......................] - ETA: 5:07 - loss: 4.9115 - confidence_loss: 0.0272
# Epoch 2: loss did not improve from 0.88802
# 206/662 [========>.....................] - ETA: 5:00 - loss: 4.9728 - confidence_loss: 0.0269
# Epoch 2: loss did not improve from 0.88802
# 216/662 [========>.....................] - ETA: 4:54 - loss: 5.0354 - confidence_loss: 0.0267
# Epoch 2: loss did not improve from 0.88802
# 226/662 [=========>....................] - ETA: 4:47 - loss: 5.0977 - confidence_loss: 0.0266
# Epoch 2: loss did not improve from 0.88802
# 236/662 [=========>....................] - ETA: 4:41 - loss: 5.1617 - confidence_loss: 0.0263
# Epoch 2: loss did not improve from 0.88802
# 246/662 [==========>...................] - ETA: 4:34 - loss: 5.2272 - confidence_loss: 0.0262
# Epoch 2: loss did not improve from 0.88802
# 256/662 [==========>...................] - ETA: 4:28 - loss: 5.2920 - confidence_loss: 0.0261
# Epoch 2: loss did not improve from 0.88802
# 266/662 [===========>..................] - ETA: 4:21 - loss: 5.3566 - confidence_loss: 0.0260
# Epoch 2: loss did not improve from 0.88802
# 276/662 [===========>..................] - ETA: 4:15 - loss: 5.4206 - confidence_loss: 0.0258
# Epoch 2: loss did not improve from 0.88802
# 286/662 [===========>..................] - ETA: 4:08 - loss: 5.4879 - confidence_loss: 0.0257
# Epoch 2: loss did not improve from 0.88802
# 296/662 [============>.................] - ETA: 4:01 - loss: 5.5556 - confidence_loss: 0.0256
# 526/662 [======================>.......] - ETA: 1:30 - loss: 7.2326 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 536/662 [=======================>......] - ETA: 1:23 - loss: 7.3111 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 546/662 [=======================>......] - ETA: 1:16 - loss: 7.3900 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 556/662 [========================>.....] - ETA: 1:10 - loss: 7.4684 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 566/662 [========================>.....] - ETA: 1:03 - loss: 7.5478 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 576/662 [=========================>....] - ETA: 57s - loss: 7.6278 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 586/662 [=========================>....] - ETA: 50s - loss: 7.7077 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 596/662 [=========================>....] - ETA: 43s - loss: 7.7898 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 606/662 [==========================>...] - ETA: 37s - loss: 7.8708 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 616/662 [==========================>...] - ETA: 30s - loss: 7.9522 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 626/662 [===========================>..] - ETA: 24s - loss: 8.0349 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 636/662 [===========================>..] - ETA: 17s - loss: 8.1185 - confidence_loss: 0.0254
# Epoch 2: loss did not improve from 0.88802
# 646/662 [============================>.] - ETA: 10s - loss: 8.2010 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 656/662 [============================>.] - ETA: 4s - loss: 8.2843 - confidence_loss: 0.0255
# Epoch 2: loss did not improve from 0.88802
# 662/662 [==============================] - 438s 661ms/step - loss: 8.3429 - confidence_loss: 0.0255
# Epoch 3/10
#   3/662 [..............................] - ETA: 7:20 - loss: 13.8551 - confidence_loss: 0.0242
# Epoch 3: loss did not improve from 0.88802
#  13/662 [..............................] - ETA: 7:08 - loss: 13.9639 - confidence_loss: 0.0243
# Epoch 3: loss did not improve from 0.88802
#  23/662 [>.............................] - ETA: 7:02 - loss: 14.0397 - confidence_loss: 0.0222
# Epoch 3: loss did not improve from 0.88802
#  33/662 [>.............................] - ETA: 6:56 - loss: 14.1443 - confidence_loss: 0.0203
# Epoch 3: loss did not improve from 0.88802
#  43/662 [>.............................] - ETA: 6:49 - loss: 14.2385 - confidence_loss: 0.0190
# Epoch 3: loss did not improve from 0.88802
#  53/662 [=>............................] - ETA: 6:43 - loss: 14.3563 - confidence_loss: 0.0180
# Epoch 3: loss did not improve from 0.88802
#  63/662 [=>............................] - ETA: 6:36 - loss: 14.4650 - confidence_loss: 0.0174
# Epoch 3: loss did not improve from 0.88802
#  73/662 [==>...........................] - ETA: 6:29 - loss: 14.5695 - confidence_loss: 0.0172
# Epoch 3: loss did not improve from 0.88802
#  83/662 [==>...........................] - ETA: 6:23 - loss: 14.6770 - confidence_loss: 0.0171
# Epoch 3: loss did not improve from 0.88802
#  93/662 [===>..........................] - ETA: 6:16 - loss: 14.7800 - confidence_loss: 0.0170
# Epoch 3: loss did not improve from 0.88802
# 103/662 [===>..........................] - ETA: 6:09 - loss: 14.8820 - confidence_loss: 0.0171
# Epoch 3: loss did not improve from 0.88802
# 113/662 [====>.........................] - ETA: 6:03 - loss: 14.9837 - confidence_loss: 0.0171
# Epoch 3: loss did not improve from 0.88802
# 123/662 [====>.........................] - ETA: 5:56 - loss: 15.0845 - confidence_loss: 0.0171
# Epoch 3: loss did not improve from 0.88802
# 133/662 [=====>........................] - ETA: 5:49 - loss: 15.1851 - confidence_loss: 0.0168
# Epoch 3: loss did not improve from 0.88802
# 143/662 [=====>........................] - ETA: 5:43 - loss: 15.2856 - confidence_loss: 0.0166
# Epoch 3: loss did not improve from 0.88802
# 153/662 [=====>........................] - ETA: 5:36 - loss: 15.3889 - confidence_loss: 0.0165
# Epoch 3: loss did not improve from 0.88802
# 163/662 [======>.......................] - ETA: 5:29 - loss: 15.4901 - confidence_loss: 0.0164
# Epoch 3: loss did not improve from 0.88802
# 173/662 [======>.......................] - ETA: 5:23 - loss: 15.5950 - confidence_loss: 0.0162
# Epoch 3: loss did not improve from 0.88802
# 183/662 [=======>......................] - ETA: 5:16 - loss: 15.7006 - confidence_loss: 0.0162
# Epoch 3: loss did not improve from 0.88802
# 193/662 [=======>......................] - ETA: 5:10 - loss: 15.8051 - confidence_loss: 0.0160
# Epoch 3: loss did not improve from 0.88802
# 203/662 [========>.....................] - ETA: 5:03 - loss: 15.9088 - confidence_loss: 0.0159
# Epoch 3: loss did not improve from 0.88802
# 213/662 [========>.....................] - ETA: 4:57 - loss: 16.0150 - confidence_loss: 0.0157
# Epoch 3: loss did not improve from 0.88802
# 223/662 [=========>....................] - ETA: 4:50 - loss: 16.1220 - confidence_loss: 0.0156
# Epoch 3: loss did not improve from 0.88802
# 233/662 [=========>....................] - ETA: 4:43 - loss: 16.2317 - confidence_loss: 0.0156
# Epoch 3: loss did not improve from 0.88802
# 243/662 [==========>...................] - ETA: 4:37 - loss: 16.3384 - confidence_loss: 0.0155
# Epoch 3: loss did not improve from 0.88802
# 253/662 [==========>...................] - ETA: 4:30 - loss: 16.4469 - confidence_loss: 0.0154
# Epoch 3: loss did not improve from 0.88802
# 263/662 [==========>...................] - ETA: 4:23 - loss: 16.5561 - confidence_loss: 0.0154
# Epoch 3: loss did not improve from 0.88802
# 273/662 [===========>..................] - ETA: 4:17 - loss: 16.6649 - confidence_loss: 0.0154
# Epoch 3: loss did not improve from 0.88802
# 283/662 [===========>..................] - ETA: 4:10 - loss: 16.7721 - confidence_loss: 0.0154
# Epoch 3: loss did not improve from 0.88802
# 293/662 [============>.................] - ETA: 4:04 - loss: 16.8816 - confidence_loss: 0.0153
# Epoch 3: loss did not improve from 0.88802
# 303/662 [============>.................] - ETA: 3:57 - loss: 16.9927 - confidence_loss: 0.0153
# Epoch 3: loss did not improve from 0.88802
# 313/662 [=============>................] - ETA: 3:50 - loss: 17.1027 - confidence_loss: 0.0152
# 127/662 [====>.........................] - ETA: 5:54 - loss: 51.2318 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 137/662 [=====>........................] - ETA: 5:48 - loss: 51.3986 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 147/662 [=====>........................] - ETA: 5:41 - loss: 51.5694 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 157/662 [======>.......................] - ETA: 5:34 - loss: 51.7443 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 167/662 [======>.......................] - ETA: 5:28 - loss: 51.9155 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 177/662 [=======>......................] - ETA: 5:21 - loss: 52.0867 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 187/662 [=======>......................] - ETA: 5:14 - loss: 52.2581 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 197/662 [=======>......................] - ETA: 5:08 - loss: 52.4293 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 207/662 [========>.....................] - ETA: 5:01 - loss: 52.5988 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 217/662 [========>.....................] - ETA: 4:55 - loss: 52.7729 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 227/662 [=========>....................] - ETA: 4:48 - loss: 52.9443 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 237/662 [=========>....................] - ETA: 4:41 - loss: 53.1151 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 247/662 [==========>...................] - ETA: 4:35 - loss: 53.2901 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 257/662 [==========>...................] - ETA: 4:28 - loss: 53.4627 - confidence_loss: 0.0063
# Epoch 5: loss did not improve from 0.88802
# 267/662 [===========>..................] - ETA: 4:21 - loss: 53.6345 - confidence_loss: 0.0063
# Epoch 5: loss did not improve from 0.88802
# 277/662 [===========>..................] - ETA: 4:15 - loss: 53.8082 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 287/662 [===========>..................] - ETA: 4:08 - loss: 53.9814 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 297/662 [============>.................] - ETA: 4:02 - loss: 54.1562 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 307/662 [============>.................] - ETA: 3:55 - loss: 54.3307 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 317/662 [=============>................] - ETA: 3:48 - loss: 54.5080 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 327/662 [=============>................] - ETA: 3:42 - loss: 54.6829 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 337/662 [==============>...............] - ETA: 3:35 - loss: 54.8589 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 347/662 [==============>...............] - ETA: 3:29 - loss: 55.0354 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 357/662 [===============>..............] - ETA: 3:22 - loss: 55.2112 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 367/662 [===============>..............] - ETA: 3:15 - loss: 55.3871 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 377/662 [================>.............] - ETA: 3:09 - loss: 55.5639 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 387/662 [================>.............] - ETA: 3:02 - loss: 55.7423 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 397/662 [================>.............] - ETA: 2:55 - loss: 55.9196 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 407/662 [=================>............] - ETA: 2:49 - loss: 56.0972 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 417/662 [=================>............] - ETA: 2:42 - loss: 56.2760 - confidence_loss: 0.0062
# Epoch 5: loss did not improve from 0.88802
# 427/662 [==================>...........] - ETA: 2:36 - loss: 56.4556 - confidence_loss: 0.0063
# Epoch 5: loss did not improve from 0.88802
# 437/662 [==================>...........] - ETA: 2:29 - loss: 56.6346 - confidence_loss: 0.0063
# Epoch 5: loss did not improve from 0.88802
# 447/662 [===================>..........] - ETA: 2:22 - loss: 56.8137 - confidence_loss: 0.0063
# Epoch 5: loss did not improve from 0.88802
# 457/662 [===================>..........] - ETA: 2:16 - loss: 56.9929 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 467/662 [====================>.........] - ETA: 2:09 - loss: 57.1724 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 477/662 [====================>.........] - ETA: 2:02 - loss: 57.3517 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 487/662 [=====================>........] - ETA: 1:56 - loss: 57.5317 - confidence_loss: 0.0064
# Epoch 5: loss did not improve from 0.88802
# 497/662 [=====================>........] - ETA: 1:49 - loss: 57.7114 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 507/662 [=====================>........] - ETA: 1:43 - loss: 57.8920 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 517/662 [======================>.......] - ETA: 1:36 - loss: 58.0730 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 527/662 [======================>.......] - ETA: 1:29 - loss: 58.2529 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 537/662 [=======================>......] - ETA: 1:23 - loss: 58.4347 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 547/662 [=======================>......] - ETA: 1:16 - loss: 58.6159 - confidence_loss: 0.0065
# Epoch 5: loss did not improve from 0.88802
# 557/662 [========================>.....] - ETA: 1:09 - loss: 58.7971 - confidence_loss: 0.0066
# Epoch 5: loss did not improve from 0.88802
# 567/662 [========================>.....] - ETA: 1:03 - loss: 58.9796 - confidence_loss: 0.0066
# Epoch 5: loss did not improve from 0.88802
# 577/662 [=========================>....] - ETA: 56s - loss: 59.1613 - confidence_loss: 0.0066
# Epoch 9: loss did not improve from 0.88802
# 485/662 [====================>.........] - ETA: 1:57 - loss: 178.4886 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 495/662 [=====================>........] - ETA: 1:51 - loss: 178.7701 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 505/662 [=====================>........] - ETA: 1:44 - loss: 179.0509 - confidence_loss: 0.0023
# Epoch 9: loss did not improve from 0.88802
# 515/662 [======================>.......] - ETA: 1:37 - loss: 179.3323 - confidence_loss: 0.0023
# Epoch 9: loss did not improve from 0.88802
# 525/662 [======================>.......] - ETA: 1:31 - loss: 179.6153 - confidence_loss: 0.0023
# Epoch 9: loss did not improve from 0.88802
# 535/662 [=======================>......] - ETA: 1:24 - loss: 179.8971 - confidence_loss: 0.0023
# Epoch 9: loss did not improve from 0.88802
# 545/662 [=======================>......] - ETA: 1:18 - loss: 180.1807 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 555/662 [========================>.....] - ETA: 1:11 - loss: 180.4639 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 565/662 [========================>.....] - ETA: 1:04 - loss: 180.7469 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 575/662 [=========================>....] - ETA: 58s - loss: 181.0318 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 585/662 [=========================>....] - ETA: 51s - loss: 181.3157 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 595/662 [=========================>....] - ETA: 44s - loss: 181.5998 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 605/662 [==========================>...] - ETA: 38s - loss: 181.8837 - confidence_loss: 0.0024
# Epoch 9: loss did not improve from 0.88802
# 615/662 [==========================>...] - ETA: 31s - loss: 182.1682 - confidence_loss: 0.0025
# Epoch 9: loss did not improve from 0.88802
# 625/662 [===========================>..] - ETA: 24s - loss: 182.4533 - confidence_loss: 0.0025
# Epoch 9: loss did not improve from 0.88802
# 635/662 [===========================>..] - ETA: 18s - loss: 182.7378 - confidence_loss: 0.0025
# Epoch 9: loss did not improve from 0.88802
# 645/662 [============================>.] - ETA: 11s - loss: 183.0225 - confidence_loss: 0.0025
# Epoch 9: loss did not improve from 0.88802
# 655/662 [============================>.] - ETA: 4s - loss: 183.3076 - confidence_loss: 0.0025
# Epoch 9: loss did not improve from 0.88802
# 662/662 [==============================] - 441s 666ms/step - loss: 183.5351 - confidence_loss: 0.0025
# Epoch 10/10
#   2/662 [..............................] - ETA: 7:23 - loss: 202.4515 - confidence_loss: 0.0023
# Epoch 10: loss did not improve from 0.88802
#  12/662 [..............................] - ETA: 7:12 - loss: 202.7381 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
#  22/662 [..............................] - ETA: 7:05 - loss: 203.0598 - confidence_loss: 0.0025
# Epoch 10: loss did not improve from 0.88802
#  32/662 [>.............................] - ETA: 6:59 - loss: 203.3520 - confidence_loss: 0.0024
# Epoch 10: loss did not improve from 0.88802
#  42/662 [>.............................] - ETA: 6:52 - loss: 203.6434 - confidence_loss: 0.0023
# Epoch 10: loss did not improve from 0.88802
#  52/662 [=>............................] - ETA: 6:45 - loss: 203.9370 - confidence_loss: 0.0023
# Epoch 10: loss did not improve from 0.88802
#  62/662 [=>............................] - ETA: 6:39 - loss: 204.2331 - confidence_loss: 0.0023
# Epoch 10: loss did not improve from 0.88802
#  72/662 [==>...........................] - ETA: 6:32 - loss: 204.5260 - confidence_loss: 0.0023
# Epoch 10: loss did not improve from 0.88802
#  82/662 [==>...........................] - ETA: 6:26 - loss: 204.8198 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
#  92/662 [===>..........................] - ETA: 6:19 - loss: 205.1113 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 102/662 [===>..........................] - ETA: 6:13 - loss: 205.4056 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 112/662 [====>.........................] - ETA: 6:06 - loss: 205.7008 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 122/662 [====>.........................] - ETA: 5:59 - loss: 205.9965 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 132/662 [====>.........................] - ETA: 5:53 - loss: 206.2931 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 142/662 [=====>........................] - ETA: 5:46 - loss: 206.5895 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 152/662 [=====>........................] - ETA: 5:39 - loss: 206.8869 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 162/662 [======>.......................] - ETA: 5:33 - loss: 207.1836 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 172/662 [======>.......................] - ETA: 5:26 - loss: 207.4797 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 182/662 [=======>......................] - ETA: 5:19 - loss: 207.7775 - confidence_loss: 0.0020
# Epoch 10: loss did not improve from 0.88802
# 192/662 [=======>......................] - ETA: 5:13 - loss: 208.0750 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 202/662 [========>.....................] - ETA: 5:06 - loss: 208.3708 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 212/662 [========>.....................] - ETA: 4:59 - loss: 208.6717 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 222/662 [=========>....................] - ETA: 4:53 - loss: 208.9704 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 232/662 [=========>....................] - ETA: 4:46 - loss: 209.2665 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 242/662 [=========>....................] - ETA: 4:39 - loss: 209.5667 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 252/662 [==========>...................] - ETA: 4:33 - loss: 209.8647 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 262/662 [==========>...................] - ETA: 4:26 - loss: 210.1639 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 272/662 [===========>..................] - ETA: 4:19 - loss: 210.4650 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 282/662 [===========>..................] - ETA: 4:13 - loss: 210.7660 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 292/662 [============>.................] - ETA: 4:06 - loss: 211.0651 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 302/662 [============>.................] - ETA: 3:59 - loss: 211.3659 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 312/662 [=============>................] - ETA: 3:53 - loss: 211.6675 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 322/662 [=============>................] - ETA: 3:46 - loss: 211.9674 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 332/662 [==============>...............] - ETA: 3:40 - loss: 212.2692 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 342/662 [==============>...............] - ETA: 3:33 - loss: 212.5717 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 352/662 [==============>...............] - ETA: 3:26 - loss: 212.8735 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 362/662 [===============>..............] - ETA: 3:20 - loss: 213.1750 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 372/662 [===============>..............] - ETA: 3:13 - loss: 213.4774 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 382/662 [================>.............] - ETA: 3:06 - loss: 213.7792 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 392/662 [================>.............] - ETA: 3:00 - loss: 214.0817 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 402/662 [=================>............] - ETA: 2:53 - loss: 214.3837 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 412/662 [=================>............] - ETA: 2:46 - loss: 214.6865 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 422/662 [==================>...........] - ETA: 2:40 - loss: 214.9897 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 432/662 [==================>...........] - ETA: 2:33 - loss: 215.2920 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 442/662 [===================>..........] - ETA: 2:26 - loss: 215.5945 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 452/662 [===================>..........] - ETA: 2:20 - loss: 215.8977 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 462/662 [===================>..........] - ETA: 2:13 - loss: 216.2012 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 472/662 [====================>.........] - ETA: 2:06 - loss: 216.5056 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 482/662 [====================>.........] - ETA: 2:00 - loss: 216.8100 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 492/662 [=====================>........] - ETA: 1:53 - loss: 217.1142 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 502/662 [=====================>........] - ETA: 1:46 - loss: 217.4184 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 512/662 [======================>.......] - ETA: 1:40 - loss: 217.7228 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 522/662 [======================>.......] - ETA: 1:33 - loss: 218.0273 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 532/662 [=======================>......] - ETA: 1:26 - loss: 218.3319 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 542/662 [=======================>......] - ETA: 1:20 - loss: 218.6369 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 552/662 [========================>.....] - ETA: 1:13 - loss: 218.9429 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 562/662 [========================>.....] - ETA: 1:06 - loss: 219.2491 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 572/662 [========================>.....] - ETA: 1:00 - loss: 219.5554 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 582/662 [=========================>....] - ETA: 53s - loss: 219.8614 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 592/662 [=========================>....] - ETA: 46s - loss: 220.1674 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 602/662 [==========================>...] - ETA: 40s - loss: 220.4739 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 612/662 [==========================>...] - ETA: 33s - loss: 220.7803 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 622/662 [===========================>..] - ETA: 26s - loss: 221.0872 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 632/662 [===========================>..] - ETA: 20s - loss: 221.3938 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 642/662 [============================>.] - ETA: 13s - loss: 221.7015 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 652/662 [============================>.] - ETA: 6s - loss: 222.0087 - confidence_loss: 0.0022
# Epoch 10: loss did not improve from 0.88802
# 662/662 [============================>.] - ETA: 0s - loss: 222.3158 - confidence_loss: 0.0021
# Epoch 10: loss did not improve from 0.88802
# 662/662 [==============================] - 442s 667ms/step - loss: 222.3469 - confidence_loss: 0.0022

# %%
# model.load_weights('data/fish/fishdetector_weights.hdf5')

# %%
annotation = boxes['lag'][0]

_, sample_img = load_img(annotation['filename'])
pred = model.predict(np.array([sample_img,]))

decoded = decode_prediction(pred[0], conf_thr=0.2)
decoded = non_max_suppression(decoded,
                              max_output_size=5,
                              iou_threshold=0.1)

plt.figure(figsize=(6, 6), dpi=120)
img = draw_boxes(annotation, decoded, (IMG_WIDTH, IMG_HEIGHT))
plt.imshow(img)
plt.title('Предсказание модели {}x{}'.format(*img.shape));

# %%
test_images = glob('test_stg1/*.jpg')[:5]


plt.figure(figsize=(6, 4 * len(test_images)), dpi=120)

for i, filename in enumerate(test_images):
    _, sample_img = load_img(filename)
    pred = model.predict(np.array([sample_img,]))

    decoded = decode_prediction(pred[0], conf_thr=0.0)
    decoded = non_max_suppression(decoded,
                                  max_output_size=2,
                                  iou_threshold=0.1)
    
    plt.subplot(len(test_images), 1, i + 1)
    img = draw_boxes({'filename': filename}, decoded, (IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
    plt.title('Предсказание на тесте {}'.format(filename));

# %% [markdown]
# # Загружаем разметку

# %%
# TODO: предскажите класс рыбы для фотографии из тестовой выборки
#
# Подготовьте файл с предсказаниями вероятностей для каждой фотографии:
# image,ALB,BET,DOL,LAG,NoF,OTHER,SHARK,YFT
# img_00001.jpg,1,0,0,0,0,...,0
# img_00002.jpg,0.3,0.1,0.6,0,...,0

# %%
print(fish_classes)
# Out:
# ['dol' 'yft' 'shark' 'other' 'lag' 'bet' 'alb']

# %%
predictions = pd.DataFrame(columns=['image', 'ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK','YFT'])

for i, file in enumerate(tqdm(glob('../working/test_stg1/*.jpg'))):
    #bn = os.path.basename(file)
    _, sample_img = load_img(file)

    pred = model.predict(np.array([sample_img,]))[0]
    decoded = decode_prediction(pred, conf_thr=0.015)
    decoded = non_max_suppression(decoded,max_output_size=1,iou_threshold=0.5)
    decoded = decoded[0]['labels']

    predictions.loc[i, 'image'] = os.path.basename(file)
    predictions.loc[i, 'ALB'] = decoded[5]
    predictions.loc[i, 'BET'] = decoded[1]
    predictions.loc[i, 'DOL'] = decoded[4]
    predictions.loc[i, 'LAG'] = decoded[3]
    predictions.loc[i, 'SHARK'] = decoded[0]
    predictions.loc[i, 'YFT'] = decoded[2]
    predictions.loc[i, 'NoF'] = 0.123081
    predictions.loc[i, 'OTHER'] = 0.079142
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
for i, file in enumerate(tqdm(glob('test_stg2/*.jpg')), predictions.shape[0]):
    _, sample_img = load_img(file)

    pred = model.predict(np.array([sample_img,]))[0]
    decoded = decode_prediction(pred, conf_thr=0.015)
    decoded = non_max_suppression(decoded, max_output_size=1, iou_threshold=0.5)
    predictions.loc[i, 'image'] = "test_stg2/" + os.path.basename(file)
    predictions.loc[i, 'ALB'] = decoded[5]
    predictions.loc[i, 'BET'] = decoded[1]
    predictions.loc[i, 'DOL'] = decoded[4]
    predictions.loc[i, 'LAG'] = decoded[3]
    predictions.loc[i, 'SHARK'] = decoded[0]
    predictions.loc[i, 'YFT'] = decoded[2]
    predictions.loc[i, 'NoF'] = 0.123081
    predictions.loc[i, 'OTHER'] = 0.079142
# Out:
#   0%|          | 0/12153 [00:00<?, ?it/s]

# %%
predictions.to_csv("submission.csv", index=False)
print(os.listdir("./"))
# Out:
# ['.config', 'test_stg2.7z', '__MACOSX', 'test_stg1.zip', 'data', 'sample_submission_stg1.csv.zip', 'train.zip', 'train', 'test_stg1', 'the-nature-conservancy-fisheries-monitoring.zip', 'data.zip', 'submission.csv', 'test_stg2', 'fishdetector.hdf5', 'sample_submission_stg2.csv.zip', 'sample_data']
