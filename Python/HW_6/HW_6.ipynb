# %% [markdown]
# **Задание 1**
#
# Печатные газеты использовали свой формат дат для каждого выпуска. Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime:
# * The Moscow Times - Wednesday, October 2, 2002
# * The Guardian - Friday, 11.10.13
# * Daily News - Thursday, 18 August 1977

# %%
# https://docs.python.org/3/library/datetime.html?highlight=datetime#module-datetime
from datetime import datetime as dt
str_1 = 'Wednesday, October 2, 2002'
str_2 = 'Friday, 11.10.13'
str_3 = 'Thursday, 18 August 1977'

str_1_dt = dt.strptime(str_1, '%A, %B %d, %Y')
print(str_1_dt, str_1_dt.strftime('%A, %B %d, %Y'))

str_2_dt = dt.strptime(str_2, '%A, %d.%m.%y')
print(str_2_dt, str_2_dt.strftime('%A, %d.%m.%y'))

str_3_dt = dt.strptime(str_3, '%A, %d %B %Y')
print(str_3_dt, str_3_dt.strftime('%A, %d %B %Y'))
# Out:
# 2002-10-02 00:00:00 Wednesday, October 02, 2002
# 2013-10-11 00:00:00 Friday, 11.10.13
# 1977-08-18 00:00:00 Thursday, 18 August 1977

# %% [markdown]
# **Задание 2**
#
# Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения:
# stream = [‘2018-04-02’, ‘2018-02-29’, ‘2018-19-02’]
#
# Напишите функцию, которая проверяет эти даты на корректность. Т. е. для каждой даты возвращает True (дата корректна) или False (некорректная дата).

# %%
stream = ['2018-04-02', '2018-02-29', '2018-19-02']
def check_corr(stream):
    """
    Функция проверяет введенные даты на корректность YYYY-MM-DD
    Функция возвращает булевый список
    Индекс списка на входе соответствует индексу на выходе
    1 - дата введена корректно
    0 - дата введена не корректно
    """
    result = []
    from datetime import datetime as dt
    for str_dt in stream:
        result.append(1)
        try:
            dt.strptime(str_dt, '%Y-%m-%d') 
        except:
            del(result[-1])
            result.append(0)
    return result

# %%
check_corr(stream)
# Out:
# [1, 0, 0]

# %% [markdown]
# **Задание 3**
#
# Напишите функцию date_range, которая возвращает список дат за период от start_date до end_date. Даты должны вводиться в формате YYYY-MM-DD. В случае неверного формата или при start_date > end_date должен возвращаться пустой список.

# %%
# start_date = '2020-01-01'
# end_date ='2020-01-05'
def date_range(start_date, end_date):
    """
    Функция возвращает список дат в диапазоне от start_date до end_date включительно
    Если start_date > end_date возвращает пустой список
    """
    from datetime import datetime as dt
    from datetime import timedelta
    try:
        start_dt = dt.strptime(start_date, '%Y-%m-%d')
        end_dt = dt.strptime(end_date, '%Y-%m-%d')
        result = []
        while start_dt <= end_dt:
            result += [start_dt.strftime('%Y-%m-%d')]
            start_dt += timedelta(days = 1)
    except:
        return []
    return result

# print(date_range(start_date, end_date))
# Out:
# ['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05']

# %%
start_date = input('Введите начальную дату:')
end_date = input('Введите конечную дату:')
print(date_range(start_date, end_date))
# Out:
# Введите начальную дату:2020-01-01
# Введите конечную дату:2020-01-05
# ['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05']

# %% [markdown]
# **Задание 4 (бонусное)**
#
# Ваш коллега прислал код функции:
# ```
# DEFAULT_USER_COUNT = 3
#
# def delete_and_return_last_user(region, default_list=[‘A100’, ‘A101’, ‘A102’]):
# ""“
# Удаляет из списка default_list последнего пользователя
# и возвращает ID нового последнего пользователя.
# ”""
# element_to_delete = default_list[-1]
# default_list.remove(element_to_delete)
# return default_list[DEFAULT_USER_COUNT-2]
# ```
# 1.   При однократном вызове этой функции все работает корректно:
# ```
# delete_and_return_last_user(1)
# ‘A101’
# ```
# 2.   Однако, при повторном вызове получается ошибка IndexError: list index out of range.
# *Задание:*
# 1.   Что значит ошибка list index out of range?
# 2.   Почему при первом запуске функция работает корректно, а при втором - нет?

# %% [markdown]
# **Ответ**
# 1. Индекс списка (в нашем случае список default_list) к которому идет обращение выходит за рамки размеров списка, т.е (indx > len(list)-1) или (indx < -len(list))
# 2.
# * При первом запуске мы попадаем на элемент списка 2 (indx = 1) (default_list[DEFAULT_USER_COUNT-2], где DEFAULT_USER_COUNT == 3), а размерность списка на выходе 2 элемента, что и дает нам ‘A101’.
# * При втором запуске, если я правильно понял, список по умолчанию в функции default_list=['A100', 'A101', 'A102'] изменяется и уже имеет вид default_list=[‘A100’, ‘A101’], а в итоговом значении всё также идет ссылка на 2 элемент списка (indx = 1), а размерность списка на выходе 1 элемент.
#
# Видимо, задавать сложные типы данных в функциях по умолчанию, не лучшая идея. Или я чего-то не знаю.

# %%
DEFAULT_USER_COUNT = 3
 
def delete_and_return_last_user(region, default_list=['A100', 'A101', 'A102']):
    """
    Удаляет из списка default_list последнего пользователя
    и возвращает ID нового последнего пользователя.
    """
    print(default_list)
    element_to_delete = default_list[-1]
    default_list.remove(element_to_delete)
    print(default_list)
    return default_list[DEFAULT_USER_COUNT-2]

# %%
delete_and_return_last_user(1)
# Out:
# ['A100', 'A101']
# ['A100']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-bfb6c4f8c48e> in <module>()
# ----> 1 delete_and_return_last_user(1)
#
# <ipython-input-20-cc50cf21dbac> in delete_and_return_last_user(region, default_list)
#      10     default_list.remove(element_to_delete)
#      11     print(default_list)
# ---> 12     return default_list[DEFAULT_USER_COUNT-2]
#      13
#
# IndexError: list index out of range
